# %% [markdown]
# # BY04 Asset Pricing Replication

# %% [markdown]
# ## Step 1 — Set output directory
#
# You will be prompted to type the folder path where pickle files and figures are saved.

# %%
# %run 0_utils.py
# Out:
# Output directory set to: /Users/sila/Documents/GitHub/BY04_APT/output

# %% [markdown]
# ## Step 2 — Tauchen (1986) discretization
# Discretizes the expected growth process onto a 50-point grid. Saves `tauchen_data.pkl`.

# %%
# %run 1_tauchen.py
# Out:
# Grid: K = 50, x in [-0.006734, 0.006734]
# Unconditional SD of x: sigma_x = 0.001684
# Grid spacing dx = 0.000275
# Max |row sum - 1| = 2.00e-15
# Stationary dist: sum = 1.0000000000, min = 3.99e-05, max = 0.0633
# E[x] under pi = -6.16e-17 (should be ~0)
# Std[x] under pi = 0.001727 (analytical: 0.001684)
# Saved  /Users/sila/Documents/GitHub/BY04_APT/output/tauchen_data.pkl

# %% [markdown]
# ## Step 3 — Epstein-Zin and CRRA solution
# Solves the EZ fixed-point and CRRA benchmark. Saves `ez_solution.pkl` and wealth-consumption ratio figure.

# %%
# %run 2_ez_solution.py
# Out:
# Loaded /Users/sila/Documents/GitHub/BY04_APT/output/tauchen_data.pkl
# ...
# Q6: CRRA BENCHMARK
# ...
# Spectral radius of Psi^w = 0.995728 (< 1? True)
# w^CRRA: min = 22.6329, max = 1198.3178
# E[w^CRRA] = 152.7415
#
# ...
# EPSTEIN-ZIN SOLUTION
# ...
# theta = -27.00

# %% [markdown]
# ## Step 4 — Asset pricing moments
# Computes equity premium, risk-free rate, volatilities, and risk-neutral probabilities. Saves all results and figures.

# %%
# %run 3_moments.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/GitHub/BY04_APT/3_moments.py:21
#      18 save_pkl, load_pkl, save_fig = _u.save_pkl, _u.load_pkl, _u.save_fig
#      20 # Load data
# ---> 21 td = load_pkl('tauchen_data.pkl')
#      22 x, P, pi, K = td['x'], td['P'], td['pi'], td['K']
#      24 ez = load_pkl('ez_solution.pkl')
#
# File ~/Documents/GitHub/BY04_APT/0_utils.py:70, in load_pkl(filename)
#      68 """Load and return a pickled object from BASE_DIR/filename."""
#      69 path = data_path(filename)
# ---> 70 with open(path, "rb") as f:
#      71     obj = pickle.load(f)
#      72 print(f"Loaded {path}")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sila/Documents/GitHub/BY04_APT/output/tauchen_data.pkl'

# %% [markdown]
# ## Step 5 — Stress tests (Q11–Q16)
# Sweeps over persistence, IES, leverage, and risk aversion. Saves sensitivity figures.

# %%
# %run 4_stress_tests.py

# %% [markdown]
# ## Step 6 — Stochastic volatility: Case II (Q17–Q19)
# Coefficients, Table IV replication, pricing kernel decomposition, and time-varying risk premia.

# %%
# %run 5_caseII.py
# Out:
# CASE II COEFFICIENTS AND TABLE IV
# theta = -27.00
# A1 = 13.9254
# A2 = -409.6157
# lambda_{m,eta} = -10.0000
# lambda_{m,e} = 17.1047
# lambda_{m,w} = -11434.8319
#
# A1m = 97.4781
# A2m = -2546.8468
# beta_{m,e} = 4.276169
# beta_{m,w} = -2539.206278
#
# --- Conditional EP at sigma^2_t = sigma^2 ---
# Risk comp (e): 5.3400%
# Risk comp (w): 0.1843%
# Jensen:        -1.4272%
# EP annual:     4.10%
#
# --- Table IV (gamma=10) ---
# E[rm - rf]   = 4.10%   (Paper: 6.84%)
# E[rf]        = 2.62%   (Paper: 0.93%)
# sigma(Rm)    = 16.90%   (Paper: 18.65%)
# sigma(Rf)    = 0.39%   (Paper: 0.57%)
# sigma(p-d)   = 0.1681    (Paper: 0.21)
#
# Q18: PRICING KERNEL DECOMPOSITION
# Variance shares:
#   eta (consumption):     24.8%  (Paper: 14%)
#   e   (expected growth): 72.4%  (Paper: 47%)
#   w   (volatility):      2.8%  (Paper: 39%)
# Annualized max Sharpe ratio: 0.54  (Paper: 0.73)
#
# --- Sensitivity: rho = 0.95 ---
#   eta: 61.8%
#   e:   37.1%
#   w:   1.1%
#   Max SR: 0.34
#
# ...
